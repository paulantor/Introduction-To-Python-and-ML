# %%
t = int(input())

for i in range(t):
    n = int(input())
    if n == 0:
        print(0)
        continue

    while n > 0:
        digit = n % 10
        print(digit, end=" ")
        n = n // 10
    print()
# Out:
# 6 5 4 3
# 5 4 3
# 6 5 4 3
# 2 2 3 4 4
