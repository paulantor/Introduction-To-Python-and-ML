# %%
count=1
val1="Inside the while loop"
val2="Outside the while loop"
while count<10:
    print(f"{count} is :{val1}")
    count+=1
print(f"{count} is :{val2}")
# Out:
# 1 is :Inside the while loop
# 2 is :Inside the while loop
# 3 is :Inside the while loop
# 4 is :Inside the while loop
# 5 is :Inside the while loop
# 6 is :Inside the while loop
# 7 is :Inside the while loop
# 8 is :Inside the while loop
# 9 is :Inside the while loop
# 10 is :Outside the while loop
