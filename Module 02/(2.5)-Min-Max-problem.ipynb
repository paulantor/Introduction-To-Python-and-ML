# %%
i=input().split()
a=int(i[0])
b=int(i[1])
c=int(i[2])
mx=0;mn=0
if(a>=b and a>=c):
    mx=a
elif(c>=b and c>=a):
    mx=c
else:
    mx=b
if(a<=b and a<=c):
    mn=a
elif(c<=b and c<=a):
    mn=c
else:
    mn=b            
print(mn,mx)
# Out:
# 67564 89877
