# %%
d=input().split()

digit1=int(d[0])
digit2=int(d[1])
sum=(digit1%10)+(digit2%10)

print(sum)
# split () method diye amra input ke alada alada kore niye ashte pari. Jemon uporer code a amra input ke space diye alada kore niye aschi.
# Out:
# 5
